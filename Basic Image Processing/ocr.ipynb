# %%
from PIL import Image
import numpy as np
import pytesseract
import cv2
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
image=mpimg.imread('/Users/siddharthnayak/Downloads/id.jpg')
image1=cv2.imread('/Users/siddharthnayak/Downloads/id.jpg')
gray=cv2.cvtColor(image1,cv2.COLOR_RGB2GRAY)
plt.imshow(cv2.cvtColor(image1,cv2.COLOR_RGB2GRAY))
#cv2.imshow('gray_image',gray) 
'''print(type(image))
gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
plt.imshow(gray)'''
# Out:
# 'print(type(image))\ngray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)\nplt.imshow(gray)'

# %%
gray=cv2.medianBlur(gray,3)

# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import imutils

ap = argparse.ArgumentParser()
ap.add_argument("-i", "--image", required=True,help="path to input image to be OCR'd")
args = vars(ap.parse_args())

image = cv2.imread('/Users/siddharthnayak/Downloads/id.jpg')
image = imutils.resize(image,1024,665)
image = image[200:440,290:660]
cv2.imshow('image0',image)
cv2.waitKey(0)
h0,w0 = image.shape[:2]
h = int(h0/4) + 5

strs = ["" for x in range(4)]

for i in range(4):
    im = image[h*i:h*(i+1),:]
    gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    gray = cv2.threshold(gray,120, 255,cv2.THRESH_BINARY)[1]
    gray = cv2.medianBlur(gray, 3)
    #cv2.imshow('gray',gray)
    #cv2.waitKey(0)

    filename = "{}.png".format(os.getpid())
    cv2.imwrite(filename, gray)

    text = pytesseract.image_to_string(Image.open(filename))
    os.remove(filename)
    strs[i] = text

print("Name: ",strs[0])
print("Course: ",strs[1])
print("Department: ",strs[2])
print("Roll Number: ",strs[3])
# Out:
# usage: ipykernel_launcher.py [-h] -i IMAGE
# ipykernel_launcher.py: error: the following arguments are required: -i/--image
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import imutils

# %%
image = cv2.imread('/Users/siddharthnayak/Desktop/ren.png')
image = imutils.resize(image,1024,665)
#image = image[200:440,290:800]
cv2.imshow('image0',image)
cv2.waitKey(33)
h0,w0 = image.shape[:2]
h = int(h0/4) + 5

# %%
strs = ["" for x in range(4)]

for i in range(4):
    im = image[h*i:h*(i+1),:]
    gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    gray = cv2.threshold(gray,120, 255,cv2.THRESH_BINARY)[1]
    gray = cv2.medianBlur(gray, 3)
    #cv2.imshow('gray',gray)
    #cv2.waitKey(0)

    filename = "{}.png".format(os.getpid())
    cv2.imwrite(filename, gray)

    text = pytesseract.image_to_string(Image.open(filename))
    os.remove(filename)
    strs[i] = text

print("Name: ",strs[0])
print("Course: ",strs[1])
print("Department: ",strs[2])
print("Roll Number: ",strs[3])
# Out:
# Name:  5,3.2 Carrier lniedion
# Course:  From the dthllSMUl] 1n the prawns suclmn. “c cxpucl the mummy carrier
#
# 1“ In lun-v \rll" vhn ul ».( In‘hk
#
#
#
# mu‘muuuuvinn nu punk x;lll‘ ”I u n," q."
# Department:  umunumnm w n V&lkll .\|\I\. u. .. u 11 um...”
#
# hcmuxc (){xmiulmns III (In dilmxum ofcumcrs acrms lhcmnmion Tha cqul-
#
#
#
# n. .mv u Au: n: \. u! ,1 .uu . m.
# Roll Number:  llhl‘lllm mno OI 1101C COHCCHII’HUOHS ()l‘. L‘IlCh 810C

# %%
cv2.destroyAllWindows()

# %%
strs
# Out:
# ['5,3.2 Carrier lniedion',
#  'From the dthllSMUl] 1n the prawns suclmn. “c cxpucl the mummy carrier\n\n1“ In lun-v \\rll" vhn ul ».( In‘hk\n\n \n\nmu‘muuuuvinn nu punk x;lll‘ ”I u n," q."',
#  'umunumnm w n V&lkll .\\|\\I\\. u. .. u 11 um...”\n\nhcmuxc (){xmiulmns III (In dilmxum ofcumcrs acrms lhcmnmion Tha cqul-\n\n \n\nn. .mv u Au: n: \\. u! ,1 .uu . m.',
#  'llhl‘lllm mno OI 1101C COHCCHII’HUOHS ()l‘. L‘IlCh 810C']
